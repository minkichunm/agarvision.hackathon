# %% [markdown]
# # EfficientNet Implementation   - EfficientNet- B0
#
# ## Training a Custom  Model from scratch

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Data Pre Processing

# %%
import numpy as np
import tensorflow as tf

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import os

dataset_path = os.listdir('dataset')

print (dataset_path)  #what kinds of classes are in this dataset

print("Types of classes labels found: ", len(dataset_path))
# Out:
# ['bacteria', 'clear']
# Types of classes labels found:  2

# %%
class_labels = []

for item in dataset_path:
 # Get all the file names
 all_classes = os.listdir('dataset' + '/' +item)
 #print(all_classes)

 # Add them to the list
 for room in all_classes:
    class_labels.append((item, str('dataset_path' + '/' +item) + '/' + room))
    #print(class_labels[:5])

# %%
# Build a dataframe        
df = pd.DataFrame(data=class_labels, columns=['Labels', 'image'])
print(df.head())
# Out:
#         Labels                              image
# 0     infected        dataset_path/infected/1.jpg
# 1     infected     dataset_path/infected/1015.jpg
# 2  notinfected  dataset_path/notinfected/1011.jpg

# %%
# Let's check how many samples for each category are present
print("Total number of images in the dataset: ", len(df))

label_count = df['Labels'].value_counts()
print(label_count)
# Out:
# Total number of images in the dataset:  3
# infected       2
# notinfected    1
# Name: Labels, dtype: int64

# %%
import cv2
path = 'dataset/'
dataset_path = os.listdir('dataset')

im_size = 224

images = []
labels = []

for i in dataset_path:
    data_path = path + str(i)  
    filenames = [i for i in os.listdir(data_path) ]
   
    for f in filenames:
        img = cv2.imread(data_path + '/' + f)
        img = cv2.resize(img, (im_size, im_size))
        images.append(img)
        labels.append(i)

# %%
#This model takes input images of shape (224, 224, 3), and the input data should range [0, 255]. 

images = np.array(images)

images = images.astype('float32') / 255.0
images.shape
# Out:
# (3, 224, 224, 3)

# %%
from sklearn.preprocessing import LabelEncoder , OneHotEncoder
y=df['Labels'].values
print(y)

y_labelencoder = LabelEncoder ()
y = y_labelencoder.fit_transform (y)
print (y)
# Out:
# ['infected' 'infected' 'notinfected']
# [0 0 1]

# %%
y=y.reshape(-1,1)

from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([('my_ohe', OneHotEncoder(), [0])], remainder='passthrough')
Y = ct.fit_transform(y) #.toarray()
print(Y[:5])
print(Y[35:])
# Out:
# [[1. 0.]
#  [1. 0.]
#  [0. 1.]]
# []

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split


images, Y = shuffle(images, Y, random_state=1)


train_x, test_x, train_y, test_y = train_test_split(images, Y, test_size=0.05, random_state=415)

#inpect the shape of the training and testing.
print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# (2, 224, 224, 3)
# (2, 2)
# (1, 224, 224, 3)
# (1, 2)

# %% [markdown]
# # EfficientNet Implementation :

# %%
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetB0

NUM_CLASSES = 2
IMG_SIZE = 224
size = (IMG_SIZE, IMG_SIZE)


inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))


# Using model without transfer learning

outputs = EfficientNetB0(include_top=True, weights=None, classes=NUM_CLASSES)(inputs)

# %%
model = tf.keras.Model(inputs, outputs)

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"] )

model.summary()

hist = model.fit(train_x, train_y, epochs=30, verbose=2)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  efficientnetb0 (Functional  (None, 2)                 4052133
#  )
#
# =================================================================
# Total params: 4052133 (15.46 MB)
# Trainable params: 4010110 (15.30 MB)
# Non-trainable params: 42023 (164.16 KB)
# _________________________________________________________________
# Epoch 1/30
# WARNING:tensorflow:From C:\Users\andra\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\andra\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1/1 - 44s - loss: 1.7474 - accuracy: 0.5000 - 44s/epoch - 44s/step
# Epoch 2/30
# 1/1 - 1s - loss: 36.6155 - accuracy: 0.0000e+00 - 532ms/epoch - 532ms/step
# Epoch 3/30
# 1/1 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - 570ms/epoch - 570ms/step
# Epoch 4/30
# 1/1 - 1s - loss: 5.9605e-08 - accuracy: 1.0000 - 565ms/epoch - 565ms/step
# Epoch 5/30
# 1/1 - 1s - loss: 10.4776 - accuracy: 0.0000e+00 - 569ms/epoch - 569ms/step
# Epoch 6/30
# 1/1 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - 554ms/epoch - 554ms/step
# Epoch 7/30
# 1/1 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - 511ms/epoch - 511ms/step
# Epoch 8/30
# 1/1 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - 545ms/epoch - 545ms/step
# Epoch 9/30
# 1/1 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - 498ms/epoch - 498ms/step
# Epoch 10/30
# 1/1 - 0s - loss: 0.0072 - accuracy: 1.0000 - 471ms/epoch - 471ms/step
# Epoch 11/30
# 1/1 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - 522ms/epoch - 522ms/step
# Epoch 12/30
# 1/1 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - 470ms/epoch - 470ms/step
# Epoch 13/30
# 1/1 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - 516ms/epoch - 516ms/step
# Epoch 14/30
# 1/1 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - 467ms/epoch - 467ms/step
# Epoch 15/30
# 1/1 - 0s - loss: 35.2938 - accuracy: 0.0000e+00 - 491ms/epoch - 491ms/step
# Epoch 16/30
# 1/1 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - 495ms/epoch - 495ms/step
# Epoch 17/30
# 1/1 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - 467ms/epoch - 467ms/step
# Epoch 18/30
# 1/1 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - 495ms/epoch - 495ms/step
# Epoch 19/30
# 1/1 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - 505ms/epoch - 505ms/step
# Epoch 20/30
# 1/1 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - 457ms/epoch - 457ms/step
# Epoch 21/30
# 1/1 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - 534ms/epoch - 534ms/step
# Epoch 22/30
# 1/1 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - 474ms/epoch - 474ms/step
# Epoch 23/30
# 1/1 - 1s - loss: 21.1451 - accuracy: 0.0000e+00 - 544ms/epoch - 544ms/step
# Epoch 24/30
# 1/1 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - 481ms/epoch - 481ms/step
# Epoch 25/30
# 1/1 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - 506ms/epoch - 506ms/step
# Epoch 26/30
# 1/1 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - 489ms/epoch - 489ms/step
# Epoch 27/30
# 1/1 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - 550ms/epoch - 550ms/step
# Epoch 28/30
# 1/1 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - 478ms/epoch - 478ms/step
# Epoch 29/30
# 1/1 - 1s - loss: 0.0000e+00 - accuracy: 1.0000 - 509ms/epoch - 509ms/step
# Epoch 30/30
# 1/1 - 0s - loss: 0.0000e+00 - accuracy: 1.0000 - 475ms/epoch - 475ms/step

# %%
import matplotlib.pyplot as plt


def plot_hist(hist):
    plt.plot(hist.history["accuracy"])
    #plt.plot(hist.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()


plot_hist(hist)

# %%
preds = model.evaluate(test_x, test_y)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - accuracy: 1.0000
# Loss = 0.0
# Test Accuracy = 1.0

# %% [markdown]
# # Testing Efficient Model On Unseen data

# %%
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.utils import img_to_array


img_path = '100.jpg'

img = image.load_img(img_path, target_size=(224, 224))
x = img_to_array(img)

img = cv2.imread(img_path)
img = cv2.resize(img, (224, 224))

x = np.expand_dims(img, axis=0)
x = preprocess_input(x)

print('Input image shape:', x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 224, 224, 3)

# %%
preds=model.predict(x)
preds     # probabilities for being in each of the 2 classes
# Out:
# 1/1 [==============================] - 3s 3s/step
# array([[1.0000000e+00, 1.1694884e-08]], dtype=float32)

# %%
# Cuda and cudnn is installed for this tensorflow version. So we can see GPU is enabled
tf.config.experimental.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU')]

# %%
# %%timeit -n1 -r1 
with tf.device('/CPU:0'):
    cpu_performance =model.fit(train_x, train_y, epochs=30, verbose=2)
    cpu_performance
# Out:
# Epoch 1/30
# 4/4 - 10s - loss: 0.0314 - accuracy: 0.9794
# Epoch 2/30
# 4/4 - 10s - loss: 0.0112 - accuracy: 1.0000
# Epoch 3/30
# 4/4 - 10s - loss: 0.0575 - accuracy: 0.9794
# Epoch 4/30
# 4/4 - 10s - loss: 0.0127 - accuracy: 1.0000
# Epoch 5/30
# 4/4 - 10s - loss: 0.1307 - accuracy: 0.9691
# Epoch 6/30
# 4/4 - 9s - loss: 0.1140 - accuracy: 0.9588
# Epoch 7/30
# 4/4 - 10s - loss: 0.1884 - accuracy: 0.9485
# Epoch 8/30
# 4/4 - 10s - loss: 0.1041 - accuracy: 0.9485
# Epoch 9/30
# 4/4 - 9s - loss: 0.1310 - accuracy: 0.9794
# Epoch 10/30
# 4/4 - 10s - loss: 0.1590 - accuracy: 0.9485
# Epoch 11/30
# 4/4 - 10s - loss: 0.0269 - accuracy: 0.9897
# Epoch 12/30
# 4/4 - 10s - loss: 0.3513 - accuracy: 0.9381
# Epoch 13/30
# 4/4 - 10s - loss: 0.0182 - accuracy: 0.9897
# Epoch 14/30
# 4/4 - 10s - loss: 0.1573 - accuracy: 0.9278
# Epoch 15/30
# 4/4 - 10s - loss: 0.1249 - accuracy: 0.9588
# Epoch 16/30
# 4/4 - 10s - loss: 0.2126 - accuracy: 0.9278
# Epoch 17/30
# 4/4 - 10s - loss: 0.0770 - accuracy: 0.9691
# Epoch 18/30
# 4/4 - 10s - loss: 0.0753 - accuracy: 0.9691
# Epoch 19/30
# 4/4 - 10s - loss: 0.0125 - accuracy: 1.0000
# Epoch 20/30
# 4/4 - 10s - loss: 0.2589 - accuracy: 0.9691
# Epoch 21/30
# 4/4 - 10s - loss: 0.2965 - accuracy: 0.9072
# Epoch 22/30
# 4/4 - 10s - loss: 0.2434 - accuracy: 0.9278
# Epoch 23/30
# 4/4 - 11s - loss: 0.1788 - accuracy: 0.9381
# Epoch 24/30
# 4/4 - 10s - loss: 0.4289 - accuracy: 0.9175
# Epoch 25/30
# 4/4 - 10s - loss: 0.5336 - accuracy: 0.8969
# Epoch 26/30
# 4/4 - 10s - loss: 0.2831 - accuracy: 0.8660
# Epoch 27/30
# 4/4 - 16s - loss: 0.1846 - accuracy: 0.9588
# Epoch 28/30
# 4/4 - 10s - loss: 0.1903 - accuracy: 0.9485
# Epoch 29/30
# 4/4 - 14s - loss: 0.1100 - accuracy: 0.9588
# Epoch 30/30
# 4/4 - 15s - loss: 0.1196 - accuracy: 0.9691
# 7min 53s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# %%timeit -n1 -r1 
with tf.device('/GPU:0'):
    gpu_performance =model.fit(train_x, train_y, epochs=30, verbose=2)
    gpu_performance
# Out:
# Epoch 1/30
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0710s vs `on_train_batch_end` time: 0.1970s). Check your callbacks.
# 4/4 - 1s - loss: 0.2818 - accuracy: 0.9278
# Epoch 2/30
# 4/4 - 1s - loss: 0.1793 - accuracy: 0.9588
# Epoch 3/30
# 4/4 - 1s - loss: 0.1113 - accuracy: 0.9588
# Epoch 4/30
# 4/4 - 1s - loss: 0.1415 - accuracy: 0.9588
# Epoch 5/30
# 4/4 - 1s - loss: 0.3826 - accuracy: 0.9485
# Epoch 6/30
# 4/4 - 1s - loss: 0.0562 - accuracy: 0.9794
# Epoch 7/30
# 4/4 - 1s - loss: 0.1397 - accuracy: 0.9691
# Epoch 8/30
# 4/4 - 1s - loss: 0.2192 - accuracy: 0.9072
# Epoch 9/30
# 4/4 - 1s - loss: 0.0741 - accuracy: 0.9588
# Epoch 10/30
# 4/4 - 1s - loss: 0.3673 - accuracy: 0.9072
# Epoch 11/30
# 4/4 - 1s - loss: 0.0513 - accuracy: 0.9794
# Epoch 12/30
# 4/4 - 1s - loss: 0.0676 - accuracy: 0.9897
# Epoch 13/30
# 4/4 - 1s - loss: 0.0743 - accuracy: 0.9794
# Epoch 14/30
# 4/4 - 1s - loss: 0.0084 - accuracy: 1.0000
# Epoch 15/30
# 4/4 - 1s - loss: 0.0847 - accuracy: 0.9691
# Epoch 16/30
# 4/4 - 1s - loss: 0.0291 - accuracy: 0.9897
# Epoch 17/30
# 4/4 - 1s - loss: 0.1700 - accuracy: 0.9381
# Epoch 18/30
# 4/4 - 1s - loss: 0.0905 - accuracy: 0.9691
# Epoch 19/30
# 4/4 - 1s - loss: 0.0990 - accuracy: 0.9485
# Epoch 20/30
# 4/4 - 1s - loss: 0.0211 - accuracy: 1.0000
# Epoch 21/30
# 4/4 - 1s - loss: 0.0792 - accuracy: 0.9691
# Epoch 22/30
# 4/4 - 1s - loss: 0.0382 - accuracy: 0.9794
# Epoch 23/30
# 4/4 - 1s - loss: 0.0165 - accuracy: 0.9897
# Epoch 24/30
# 4/4 - 1s - loss: 0.0193 - accuracy: 0.9897
# Epoch 25/30
# 4/4 - 1s - loss: 0.0490 - accuracy: 0.9794
# Epoch 26/30
# 4/4 - 1s - loss: 0.0581 - accuracy: 0.9794
# Epoch 27/30
# 4/4 - 1s - loss: 0.0185 - accuracy: 0.9897
# Epoch 28/30
# 4/4 - 1s - loss: 0.0509 - accuracy: 0.9794
# Epoch 29/30
# 4/4 - 1s - loss: 0.0035 - accuracy: 1.0000
# Epoch 30/30
# 4/4 - 1s - loss: 0.0310 - accuracy: 0.9897
# 25.6 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# CPU completed the training in 7 min 53 Seconds and GPU did that training in 25.6 seconds
